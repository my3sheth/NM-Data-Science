# %% [markdown]
# <a href="https://colab.research.google.com/github/my3sheth/NM-Data-Science/blob/master/IMDb_Top_1%2C000_Movies_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## ***2 MODELS :***
# ### *1) Machine Learning: Regression Model*
# ### *2) Deep Learning: ANN (Artificial Neural Network) Model*

# %% [markdown]
# Below is the list of all the libraries required in this project.

# %%
import pandas as pd
import  numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import math
from math import sqrt
import datetime
import warnings
warnings.filterwarnings('ignore')

from sklearn.metrics import accuracy_score
from sklearn.preprocessing import LabelEncoder
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import mutual_info_regression
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from sklearn import metrics
from sklearn.metrics import r2_score

import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LeakyReLU, ReLU
from keras.layers import Dropout

# %%
data=pd.read_csv('/content/IMDB Movies copy.csv')

# %%
data.head()
# Out:
#                       Title  Year_of_Release Certificate  Runtime   Genre  \
# 0  The Shawshank Redemption             1994           A      142   Drama
# 1             The Godfather             1972           A      175   Crime
# 2           The Dark Knight             2008          UA      152  Action
# 3    The Godfather: Part II             1974           A      202   Crime
# 4              12 Angry Men             1957           U       96   Crime
#
#    Rating                                           Overview  Meta_Score  \
# 0     9.3  Two imprisoned men bond over a number of years...        80.0
# 1     9.2  An organized crime dynasty's aging patriarch t...       100.0
# 2     9.0  When the menace known as the Joker wreaks havo...        84.0
# 3     9.0  The early life and career of Vito Corleone in ...        90.0
# 4     9.0  A jury holdout attempts to prevent a miscarria...        96.0
#
#                Director          Star_1          Star_2         Star_3  \
# 0        Frank Darabont     Tim Robbins  Morgan Freeman     Bob Gunton
# 1  Francis Ford Coppola   Marlon Brando       Al Pacino     James Caan
# 2     Christopher Nolan  Christian Bale    Heath Ledger  Aaron Eckhart
# 3  Francis Ford Coppola       Al Pacino  Robert De Niro  Robert Duvall
# 4          Sidney Lumet     Henry Fonda     Lee J. Cobb  Martin Balsam
#
#            Star_4  Total_Votes    Revenue
# 0  William Sadler      2343110   28341469
# 1    Diane Keaton      1620367  134966411
# 2   Michael Caine      2303232  534858444
# 3    Diane Keaton      1129952   57300000
# 4    John Fiedler       689845    4360000

# %% [markdown]
# # ***I. Machine Learning***

# %% [markdown]
# # *1. EDA (Exploratory Data Analysis)*

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Title            1000 non-null   object
#  1   Year_of_Release  1000 non-null   int64
#  2   Certificate      1000 non-null   object
#  3   Runtime          1000 non-null   int64
#  4   Genre            1000 non-null   object
#  5   Rating           1000 non-null   float64
#  6   Overview         1000 non-null   object
#  7   Meta_Score       843 non-null    float64
#  8   Director         1000 non-null   object
#  9   Star_1           1000 non-null   object
#  10  Star_2           1000 non-null   object
#  11  Star_3           1000 non-null   object
#  12  Star_4           1000 non-null   object
#  13  Total_Votes      1000 non-null   int64
#  14  Revenue          1000 non-null   int64
# dtypes: float64(2), int64(4), object(9)
# memory usage: 117.3+ KB

# %% [markdown]
# ### ***Observation:***
# There are no null columns. However, 'Meta_Score' seems to hold some null values.

# %%
data.duplicated().any()
# Out:
# False

# %% [markdown]
# ### ***Observation:***
# No duplicate values.

# %%
data.describe()
# Out:
#        Year_of_Release      Runtime       Rating  Meta_Score   Total_Votes  \
# count      1000.000000  1000.000000  1000.000000  843.000000  1.000000e+03
# mean       1991.221000   122.891000     7.949300   77.971530  2.736929e+05
# std          23.285669    28.093671     0.275491   12.376099  3.273727e+05
# min        1920.000000    45.000000     7.600000   28.000000  2.508800e+04
# 25%        1976.000000   103.000000     7.700000   70.000000  5.552625e+04
# 50%        1999.000000   119.000000     7.900000   79.000000  1.385485e+05
# 75%        2009.000000   137.000000     8.100000   87.000000  3.741612e+05
# max        2020.000000   321.000000     9.300000  100.000000  2.343110e+06
#
#             Revenue
# count  1.000000e+03
# mean   6.245165e+07
# std    1.051148e+08
# min    1.305000e+03
# 25%    2.351568e+06
# 50%    1.791714e+07
# 75%    7.410387e+07
# max    9.366622e+08

# %%
data.corr()
# Out:
#                  Year_of_Release   Runtime    Rating  Meta_Score  Total_Votes  \
# Year_of_Release         1.000000  0.165873 -0.131152   -0.339279     0.241779
# Runtime                 0.165873  1.000000  0.243096   -0.031452     0.173264
# Rating                 -0.131152  0.243096  1.000000    0.268531     0.494979
# Meta_Score             -0.339279 -0.031452  0.268531    1.000000    -0.018507
# Total_Votes             0.241779  0.173264  0.494979   -0.018507     1.000000
# Revenue                 0.237407  0.126779  0.079927   -0.036344     0.559170
#
#                   Revenue
# Year_of_Release  0.237407
# Runtime          0.126779
# Rating           0.079927
# Meta_Score      -0.036344
# Total_Votes      0.559170
# Revenue          1.000000

# %%
data.head()
# Out:
#                       Title  Year_of_Release Certificate  Runtime   Genre  \
# 0  The Shawshank Redemption             1994           A      142   Drama
# 1             The Godfather             1972           A      175   Crime
# 2           The Dark Knight             2008          UA      152  Action
# 3    The Godfather: Part II             1974           A      202   Crime
# 4              12 Angry Men             1957           U       96   Crime
#
#    Rating                                           Overview  Meta_Score  \
# 0     9.3  Two imprisoned men bond over a number of years...        80.0
# 1     9.2  An organized crime dynasty's aging patriarch t...       100.0
# 2     9.0  When the menace known as the Joker wreaks havo...        84.0
# 3     9.0  The early life and career of Vito Corleone in ...        90.0
# 4     9.0  A jury holdout attempts to prevent a miscarria...        96.0
#
#                Director          Star_1          Star_2         Star_3  \
# 0        Frank Darabont     Tim Robbins  Morgan Freeman     Bob Gunton
# 1  Francis Ford Coppola   Marlon Brando       Al Pacino     James Caan
# 2     Christopher Nolan  Christian Bale    Heath Ledger  Aaron Eckhart
# 3  Francis Ford Coppola       Al Pacino  Robert De Niro  Robert Duvall
# 4          Sidney Lumet     Henry Fonda     Lee J. Cobb  Martin Balsam
#
#            Star_4  Total_Votes    Revenue
# 0  William Sadler      2343110   28341469
# 1    Diane Keaton      1620367  134966411
# 2   Michael Caine      2303232  534858444
# 3    Diane Keaton      1129952   57300000
# 4    John Fiedler       689845    4360000

# %% [markdown]
# # *2. Preprocessing*
# ### (i) Encoding - conversion of categorical values into numerical values.

# %%
today=datetime.date.today()
Age=today.year-data['Year_of_Release']
data.insert(1,"Age",Age)
data.drop('Year_of_Release', axis = 1, inplace = True)

encoder=LabelEncoder()
data.Certificate=encoder.fit_transform(data['Certificate'])
c_mapping=dict(zip(encoder.classes_,encoder.transform(encoder.classes_)))
c_values=pd.Series(c_mapping)
print('Certificate:-\n')
print(c_values)


data.Genre=encoder.fit_transform(data['Genre'])
g_mapping=dict(zip(encoder.classes_,encoder.transform(encoder.classes_)))
g_values=pd.Series(g_mapping)
print('\nGenre:-\n')
print(g_values)
# Out:
# Certificate:-
#
# A            0
# Approved     1
# G            2
# GP           3
# PG           4
# PG-13        5
# Passed       6
# R            7
# TV-14        8
# TV-MA        9
# TV-PG       10
# U           11
# U/A         12
# UA          13
# Unrated     14
# dtype: int64
#
# Genre:-
#
# Action        0
# Adventure     1
# Animation     2
# Biography     3
# Comedy        4
# Crime         5
# Drama         6
# Family        7
# Fantasy       8
# Film-Noir     9
# Horror       10
# Mystery      11
# Thriller     12
# Western      13
# dtype: int64

# %%
data.head()
# Out:
#                       Title  Age  Certificate  Runtime  Genre  Rating  \
# 0  The Shawshank Redemption   29            0      142      6     9.3
# 1             The Godfather   51            0      175      5     9.2
# 2           The Dark Knight   15           13      152      0     9.0
# 3    The Godfather: Part II   49            0      202      5     9.0
# 4              12 Angry Men   66           11       96      5     9.0
#
#                                             Overview  Meta_Score  \
# 0  Two imprisoned men bond over a number of years...        80.0
# 1  An organized crime dynasty's aging patriarch t...       100.0
# 2  When the menace known as the Joker wreaks havo...        84.0
# 3  The early life and career of Vito Corleone in ...        90.0
# 4  A jury holdout attempts to prevent a miscarria...        96.0
#
#                Director          Star_1          Star_2         Star_3  \
# 0        Frank Darabont     Tim Robbins  Morgan Freeman     Bob Gunton
# 1  Francis Ford Coppola   Marlon Brando       Al Pacino     James Caan
# 2     Christopher Nolan  Christian Bale    Heath Ledger  Aaron Eckhart
# 3  Francis Ford Coppola       Al Pacino  Robert De Niro  Robert Duvall
# 4          Sidney Lumet     Henry Fonda     Lee J. Cobb  Martin Balsam
#
#            Star_4  Total_Votes    Revenue
# 0  William Sadler      2343110   28341469
# 1    Diane Keaton      1620367  134966411
# 2   Michael Caine      2303232  534858444
# 3    Diane Keaton      1129952   57300000
# 4    John Fiedler       689845    4360000

# %% [markdown]
# ### (ii) Imputation - detecting and handling missing/null values.

# %%
data.isnull().sum()
# Out:
# Title            0
# Age              0
# Certificate      0
# Runtime          0
# Genre            0
# Rating           0
# Overview         0
# Meta_Score     157
# Director         0
# Star_1           0
# Star_2           0
# Star_3           0
# Star_4           0
# Total_Votes      0
# Revenue          0
# dtype: int64

# %%
null=data[data['Meta_Score'].isnull()]

# %%
null.head()
# Out:
#                         Title  Age  Certificate  Runtime  Genre  Rating  \
# 20            Soorarai Pottru    3           11      153      6     8.6
# 54  Ayla: The Daughter of War    6            0      125      3     8.4
# 55               Vikram Vedha    6           13      147      0     8.4
# 57                     Dangal    7           11      161      0     8.4
# 65           Taare Zameen Par   16           11      165      6     8.4
#
#                                              Overview  Meta_Score  \
# 20  Nedumaaran Rajangam "Maara" sets out to make t...         NaN
# 54  In 1950, amid-st the ravages of the Korean War...         NaN
# 55  Vikram, a no-nonsense police officer, accompan...         NaN
# 57  Former wrestler Mahavir Singh Phogat and his t...         NaN
# 65  An eight-year-old boy is thought to be a lazy ...         NaN
#
#          Director       Star_1           Star_2              Star_3  \
# 20  Sudha Kongara       Suriya         Madhavan        Paresh Rawal
# 54      Can Ulkay    Erdem Can   Çetin Tekindor     Ismail Hacioglu
# 55        Gayatri      Pushkar         Madhavan    Vijay Sethupathi
# 57  Nitesh Tiwari   Aamir Khan    Sakshi Tanwar  Fatima Sana Shaikh
# 65     Aamir Khan  Amole Gupte  Darsheel Safary          Aamir Khan
#
#                Star_4  Total_Votes   Revenue
# 20  Aparna Balamurali        54995     12763
# 54      Kyung-jin Lee        34112     19381
# 55   Shraddha Srinath        28401   1661296
# 57     Sanya Malhotra       156479  12391761
# 65       Tisca Chopra       168895   1223869

# %%
imputer=SimpleImputer(strategy='median')
data[['Meta_Score']]=imputer.fit_transform(data[['Meta_Score']]).round(1)

# %%
data.iloc[null.index]
# Out:
#                              Title  Age  Certificate  Runtime  Genre  Rating  \
# 20                 Soorarai Pottru    3           11      153      6     8.6
# 54       Ayla: The Daughter of War    6            0      125      3     8.4
# 55                    Vikram Vedha    6           13      147      0     8.4
# 57                          Dangal    7           11      161      0     8.4
# 65                Taare Zameen Par   16           11      165      6     8.4
# ..                             ...  ...          ...      ...    ...     ...
# 872  The Day the Earth Stood Still   72           11       92      6     7.7
# 874                          Gilda   77            1      110      6     7.7
# 899                      El cuerpo   11            0      112     11     7.6
# 909                      Celda 211   14           13      113      0     7.6
# 913                      Die Welle   15           13      107      6     7.6
#
#                                               Overview  Meta_Score  \
# 20   Nedumaaran Rajangam "Maara" sets out to make t...        79.0
# 54   In 1950, amid-st the ravages of the Korean War...        79.0
# 55   Vikram, a no-nonsense police officer, accompan...        79.0
# 57   Former wrestler Mahavir Singh Phogat and his t...        79.0
# 65   An eight-year-old boy is thought to be a lazy ...        79.0
# ..                                                 ...         ...
# 872  An alien lands and tells the people of Earth t...        79.0
# 874  A small-time gambler hired to work in a Buenos...        79.0
# 899  A detective searches for the body of a femme f...        79.0
# 909  The story of two men on different sides of a p...        79.0
# 913  A high school teacher's experiment to demonstr...        79.0
#
#           Director          Star_1           Star_2              Star_3  \
# 20   Sudha Kongara          Suriya         Madhavan        Paresh Rawal
# 54       Can Ulkay       Erdem Can   Çetin Tekindor     Ismail Hacioglu
# 55         Gayatri         Pushkar         Madhavan    Vijay Sethupathi
# 57   Nitesh Tiwari      Aamir Khan    Sakshi Tanwar  Fatima Sana Shaikh
# 65      Aamir Khan     Amole Gupte  Darsheel Safary          Aamir Khan
# ..             ...             ...              ...                 ...
# 872    Robert Wise  Michael Rennie    Patricia Neal        Hugh Marlowe
# 874  Charles Vidor   Rita Hayworth       Glenn Ford     George Macready
# 899    Oriol Paulo   Jose Coronado       Hugo Silva         Belén Rueda
# 909  Daniel Monzón      Luis Tosar   Alberto Ammann     Antonio Resines
# 913  Dennis Gansel    Jürgen Vogel    Frederick Lau         Max Riemelt
#
#                 Star_4  Total_Votes   Revenue
# 20   Aparna Balamurali        54995     12763
# 54       Kyung-jin Lee        34112     19381
# 55    Shraddha Srinath        28401   1661296
# 57      Sanya Malhotra       156479  12391761
# 65        Tisca Chopra       168895   1223869
# ..                 ...          ...       ...
# 872          Sam Jaffe        76315     53309
# 874     Joseph Calleia        27991     53509
# 899       Aura Garrido        57549  37707919
# 909       Manuel Morón        63882  35014392
# 913    Jennifer Ulrich       102742   3186012
#
# [157 rows x 15 columns]

# %%
data.isnull().sum()
# Out:
# Title          0
# Age            0
# Certificate    0
# Runtime        0
# Genre          0
# Rating         0
# Overview       0
# Meta_Score     0
# Director       0
# Star_1         0
# Star_2         0
# Star_3         0
# Star_4         0
# Total_Votes    0
# Revenue        0
# dtype: int64

# %% [markdown]
# Classifying categorical and numerical columns:

# %%
data[['Rating','Meta_Score']]=data[['Rating','Meta_Score']].astype(int)
numerical=data.select_dtypes(np.int64,np.float64)
categorical=data.select_dtypes(np.object)
print(numerical.columns,'\n')
print(categorical.columns)
# Out:
# Index(['Age', 'Certificate', 'Runtime', 'Genre', 'Rating', 'Meta_Score',
#        'Total_Votes', 'Revenue'],
#       dtype='object')
#
# Index(['Title', 'Overview', 'Director', 'Star_1', 'Star_2', 'Star_3',
#        'Star_4'],
#       dtype='object')

# %%
data.head()
# Out:
#                       Title  Age  Certificate  Runtime  Genre  Rating  \
# 0  The Shawshank Redemption   29            0      142      6       9
# 1             The Godfather   51            0      175      5       9
# 2           The Dark Knight   15           13      152      0       9
# 3    The Godfather: Part II   49            0      202      5       9
# 4              12 Angry Men   66           11       96      5       9
#
#                                             Overview  Meta_Score  \
# 0  Two imprisoned men bond over a number of years...          80
# 1  An organized crime dynasty's aging patriarch t...         100
# 2  When the menace known as the Joker wreaks havo...          84
# 3  The early life and career of Vito Corleone in ...          90
# 4  A jury holdout attempts to prevent a miscarria...          96
#
#                Director          Star_1          Star_2         Star_3  \
# 0        Frank Darabont     Tim Robbins  Morgan Freeman     Bob Gunton
# 1  Francis Ford Coppola   Marlon Brando       Al Pacino     James Caan
# 2     Christopher Nolan  Christian Bale    Heath Ledger  Aaron Eckhart
# 3  Francis Ford Coppola       Al Pacino  Robert De Niro  Robert Duvall
# 4          Sidney Lumet     Henry Fonda     Lee J. Cobb  Martin Balsam
#
#            Star_4  Total_Votes    Revenue
# 0  William Sadler      2343110   28341469
# 1    Diane Keaton      1620367  134966411
# 2   Michael Caine      2303232  534858444
# 3    Diane Keaton      1129952   57300000
# 4    John Fiedler       689845    4360000

# %%
for i in numerical.columns:
  print(numerical[i].value_counts().head(),'\n')
# Out:
# 9     32
# 19    31
# 14    29
# 10    28
# 7     28
# Name: Age, dtype: int64
#
# 0     246
# 11    238
# 13    227
# 7     147
# 5      43
# Name: Certificate, dtype: int64
#
# 100    23
# 130    23
# 129    22
# 101    22
# 113    22
# Name: Runtime, dtype: int64
#
# 6    289
# 0    172
# 4    155
# 5    107
# 3     88
# Name: Genre, dtype: int64
#
# 7    537
# 8    458
# 9      5
# Name: Rating, dtype: int64
#
# 79    180
# 76     32
# 84     29
# 90     29
# 80     27
# Name: Meta_Score, dtype: int64
#
# 65341      2
# 2343110    1
# 184740     1
# 215034     1
# 126871     1
# Name: Total_Votes, dtype: int64
#
# 4360000     5
# 4360200     3
# 5321508     2
# 25000000    2
# 9600000     2
# Name: Revenue, dtype: int64

# %% [markdown]
# ### ***Observation:***
# The above data displays the count of column-wise top 5 values.

# %% [markdown]
# ### (iii) Outlier detection and handling

# %%
for i in numerical:
  plt.boxplot(numerical[i])
  plt.title(i)
  print(i)
  plt.show()
  print("\n\n")
  sns.histplot(numerical[i],kde=True,color='Maroon')
  plt.ticklabel_format(style='plain')
  plt.title(i)
  plt.show()
  print("\n\n\n\n")
# Out:
# Age
# Certificate
# Runtime
# Genre
# Rating
# Meta_Score
# Total_Votes
# Revenue

# %% [markdown]
# ### ***Observation:***
# All above columns except for 'Certificate' and 'Rating' contain outliers.

# %%
numerical.columns
# Out:
# Index(['Age', 'Certificate', 'Runtime', 'Genre', 'Rating', 'Meta_Score',
#        'Total_Votes', 'Revenue'],
#       dtype='object')

# %%
age=data.Age
q1=age.quantile(0.25)
q3=age.quantile(0.75)
iqr=q3-q1
lower=q1-1.5*iqr
upper=q3+1.5*iqr

age[(age<lower)|(age>upper)]

print(lower)
print(upper)

data.Age[data.Age<lower]=lower
data.Age[data.Age>upper]=upper

#Verifying if the outliers have been handled rightly
plt.boxplot(data['Age'])
plt.title('Age')
plt.show()
print('\n\n')
sns.histplot(data['Age'],kde=True,color='Green')
plt.title('Age')
plt.xlabel('Age')
plt.show()
# Out:
# -35.5
# 96.5

# %%
runtime=data.Runtime
q1=runtime.quantile(0.25)
q3=runtime.quantile(0.75)
iqr=q3-q1
lower=q1-1.5*iqr
upper=q3+1.5*iqr

runtime[(runtime<lower)|(runtime>upper)]

print(lower)
print(upper)

data.Runtime[data.Runtime<lower]=lower
data.Runtime[data.Runtime>upper]=upper

#Verifying if the outliers have been handled rightly
plt.boxplot(data['Runtime'])
plt.title('Runtime')
plt.show()
print('\n\n')
sns.histplot(data['Runtime'],kde=True,color='Green')
plt.title('Runtime')
plt.xlabel('Runtime')
plt.show()
# Out:
# 52.0
# 188.0

# %%
genre=data.Genre
q1=genre.quantile(0.25)
q3=genre.quantile(0.75)
iqr=q3-q1
lower=q1-1.5*iqr
upper=q3+1.5*iqr

genre[(genre<lower)|(genre>upper)]

print(lower)
print(upper)

data.Genre[data.Genre<lower]=lower
data.Genre[data.Genre>upper]=upper

#Verifying if the outliers have been handled rightly
plt.boxplot(data['Genre'])
plt.title('Genre')
plt.show()
print('\n\n')
sns.histplot(data['Genre'],kde=True,color='Green')
plt.title('Genre')
plt.xlabel('Genre')
plt.show()
# Out:
# -4.0
# 12.0

# %%
ms=data.Meta_Score
q1=ms.quantile(0.25)
q3=ms.quantile(0.75)
iqr=q3-q1
lower=q1-1.5*iqr
upper=q3+1.5*iqr

ms[(ms<lower)|(ms>upper)]

print(lower)
print(upper)

data.Meta_Score[data.Meta_Score<lower]=lower
data.Meta_Score[data.Meta_Score>upper]=upper

#Verifying if the outliers have been handled rightly
plt.boxplot(data['Meta_Score'])
plt.title('Meta Score')
plt.show()
print('\n\n')
sns.histplot(data['Meta_Score'],kde=True,color='Green')
plt.title('Meta Score')
plt.xlabel('Meta Score')
plt.show()
# Out:
# 52.125
# 105.125

# %%
votes=data.Total_Votes
q1=votes.quantile(0.25)
q3=votes.quantile(0.75)
iqr=q3-q1
lower=q1-1.5*iqr
upper=q3+1.5*iqr

votes[(votes<lower)|(votes>upper)]

print(lower)
print(upper)

data.Total_Votes[data.Total_Votes<lower]=lower
data.Total_Votes[data.Total_Votes>upper]=upper

#Verifying if the outliers have been handled rightly
plt.ticklabel_format(style='plain')
plt.boxplot(data['Total_Votes'])
plt.title('Total Votes')
plt.show()
print('\n\n')
sns.histplot(data['Total_Votes'],kde=True,color='Green')
plt.ticklabel_format(style='plain')
plt.title('Total Votes')
plt.xlabel('Total Votes')
plt.show()
# Out:
# -422426.25
# 852113.75

# %%
revenue=data.Revenue
q1=revenue.quantile(0.25)
q3=revenue.quantile(0.75)
iqr=q3-q1
lower=q1-1.5*iqr
upper=q3+1.5*iqr

revenue[(revenue<lower)|(revenue>upper)]

print(lower)
print(upper)

data.Revenue[data.Revenue<lower]=lower
data.Revenue[data.Revenue>upper]=upper

#Verifying if the outliers have been handled rightly
plt.ticklabel_format(style='plain')
plt.boxplot(data['Revenue'])
plt.title('Revenue')
plt.show()
print('\n\n')
sns.histplot(data['Revenue'],kde=True,color='Green')
plt.title('Revenue')
plt.xlabel('Revenue (in million)')
plt.show()
# Out:
# -105276885.0
# 181732323.0

# %%
data.head()
# Out:
#                       Title   Age  Certificate  Runtime  Genre  Rating  \
# 0  The Shawshank Redemption  29.0            0      142      6       9
# 1             The Godfather  51.0            0      175      5       9
# 2           The Dark Knight  15.0           13      152      0       9
# 3    The Godfather: Part II  49.0            0      188      5       9
# 4              12 Angry Men  66.0           11       96      5       9
#
#                                             Overview  Meta_Score  \
# 0  Two imprisoned men bond over a number of years...        80.0
# 1  An organized crime dynasty's aging patriarch t...       100.0
# 2  When the menace known as the Joker wreaks havo...        84.0
# 3  The early life and career of Vito Corleone in ...        90.0
# 4  A jury holdout attempts to prevent a miscarria...        96.0
#
#                Director          Star_1          Star_2         Star_3  \
# 0        Frank Darabont     Tim Robbins  Morgan Freeman     Bob Gunton
# 1  Francis Ford Coppola   Marlon Brando       Al Pacino     James Caan
# 2     Christopher Nolan  Christian Bale    Heath Ledger  Aaron Eckhart
# 3  Francis Ford Coppola       Al Pacino  Robert De Niro  Robert Duvall
# 4          Sidney Lumet     Henry Fonda     Lee J. Cobb  Martin Balsam
#
#            Star_4  Total_Votes    Revenue
# 0  William Sadler    852113.75   28341469
# 1    Diane Keaton    852113.75  134966411
# 2   Michael Caine    852113.75  181732323
# 3    Diane Keaton    852113.75   57300000
# 4    John Fiedler    689845.00    4360000

# %%
for i in numerical.columns:
  data[i]=data[i].astype(int)
for j in data['Meta_Score']:
  j=data['Meta_Score'].astype(int)

# %%
data.head()
# Out:
#                       Title  Age  Certificate  Runtime  Genre  Rating  \
# 0  The Shawshank Redemption   29            0      142      6       9
# 1             The Godfather   51            0      175      5       9
# 2           The Dark Knight   15           13      152      0       9
# 3    The Godfather: Part II   49            0      188      5       9
# 4              12 Angry Men   66           11       96      5       9
#
#                                             Overview  Meta_Score  \
# 0  Two imprisoned men bond over a number of years...          80
# 1  An organized crime dynasty's aging patriarch t...         100
# 2  When the menace known as the Joker wreaks havo...          84
# 3  The early life and career of Vito Corleone in ...          90
# 4  A jury holdout attempts to prevent a miscarria...          96
#
#                Director          Star_1          Star_2         Star_3  \
# 0        Frank Darabont     Tim Robbins  Morgan Freeman     Bob Gunton
# 1  Francis Ford Coppola   Marlon Brando       Al Pacino     James Caan
# 2     Christopher Nolan  Christian Bale    Heath Ledger  Aaron Eckhart
# 3  Francis Ford Coppola       Al Pacino  Robert De Niro  Robert Duvall
# 4          Sidney Lumet     Henry Fonda     Lee J. Cobb  Martin Balsam
#
#            Star_4  Total_Votes    Revenue
# 0  William Sadler       852113   28341469
# 1    Diane Keaton       852113  134966411
# 2   Michael Caine       852113  181732323
# 3    Diane Keaton       852113   57300000
# 4    John Fiedler       689845    4360000

# %% [markdown]
# Now, let's visualize the preprocessed data to get quick and clear insights on each variable.

# %%
plt.hist(data.Age,edgecolor='black',bins=20,color='orange')
plt.xlabel('Age')
plt.ylabel('No.of Movies')
plt.show()

# %% [markdown]
# ###***Observation:***
# #####Almost 130/1000 top movies are about a decade old. Below is the list of rows of a decade old movies.

# %%
data[data['Age']==10]
# Out:
#                                    Title  Age  Certificate  Runtime  Genre  \
# 87                              Drishyam   10           11      160      5
# 137                                Queen   10           13      146      1
# 138                          Mandariinid   10            0       87      6
# 139                   Bhaag Milkha Bhaag   10           11      186      3
# 147              The Wolf of Wall Street   10            0      180      3
# 215                     12 Years a Slave   10            0      134      3
# 216                                 Rush   10           13      123      0
# 222                            Prisoners   10            0      153      5
# 332             Kaguyahime no monogatari   10           11      137      2
# 335                      Special Chabbis   10           13      144      5
# 336                        Short Term 12   10            7       96      6
# 341                                  Her   10            0      126      6
# 359                   Dallas Buyers Club   10            7      117      3
# 478                      Before Midnight   10            7      109      6
# 588                             Le passé   10            5      130      6
# 589                   La grande bellezza   10           13      141      6
# 590                         The Lunchbox   10           11      104      6
# 593                           About Time   10            7      123      4
# 595                         Kaze tachinu   10            5      126      2
# 597                  La migliore offerta   10            7      131      5
# 604                     Captain Phillips   10           13      134      1
# 609  The Hobbit: The Desolation of Smaug   10           13      161      1
# 734                       La vie d'Adèle   10            0      180      6
# 735                          Kai po che!   10           11      130      6
# 739                             Nebraska   10           13      115      1
# 745                              Gravity   10           13       91      6
# 746              Star Trek Into Darkness   10           13      132      0
# 897                            Philomena   10            5       98      3
#
#      Rating                                           Overview  Meta_Score  \
# 87        8  A man goes to extreme lengths to save his fami...          79
# 137       8  A Delhi girl from a traditional family sets ou...          79
# 138       8  In 1992, war rages in Abkhazia, a breakaway re...          73
# 139       8  The truth behind the ascension of Milkha Singh...          79
# 147       8  Based on the true story of Jordan Belfort, fro...          75
# 215       8  In the antebellum United States, Solomon North...          96
# 216       8  The merciless 1970s rivalry between Formula On...          74
# 222       8  When Keller Dover's daughter and her friend go...          70
# 332       8  Found inside a shining stalk of bamboo by an o...          89
# 335       8  A gang of con-men rob proent rich businessmen ...          79
# 336       8  A 20-something supervising staff member of a r...          82
# 341       8  In a near future, a lonely writer develops an ...          90
# 359       8  In 1985 Dallas, electrician and hustler Ron Wo...          80
# 478       7  We meet Jesse and Celine nine years on in Gree...          94
# 588       7  An Iranian man deserts his French wife and her...          85
# 589       7  Jep Gambardella has seduced his way through th...          86
# 590       7  A mistaken delivery in Mumbai's famously effic...          76
# 593       7  At the age of 21, Tim discovers he can travel ...          55
# 595       7  A look at the life of Jiro Horikoshi, the man ...          83
# 597       7  A lonely art expert working for a mysterious a...          52
# 604       7  The true story of Captain Richard Phillips and...          82
# 609       7  The dwarves, along with Bilbo Baggins and Gand...          66
# 734       7  Adèle's life is changed when she meets Emma, a...          89
# 735       7  Three friends growing up in India at the turn ...          52
# 739       7  An aging, booze-addled father makes the trip f...          87
# 745       7  Two astronauts work together to survive after ...          96
# 746       7  After the crew of the Enterprise find an unsto...          72
# 897       7  A world-weary political journalist picks up th...          77
#
#                     Director               Star_1                    Star_2  \
# 87             Jeethu Joseph             Mohanlal                     Meena
# 137               Vikas Bahl       Kangana Ranaut             Rajkummar Rao
# 138           Zaza Urushadze        Lembit Ulfsak              Elmo Nüganen
# 139  Rakeysh Omprakash Mehra        Farhan Akhtar              Sonam Kapoor
# 147          Martin Scorsese    Leonardo DiCaprio                Jonah Hill
# 215            Steve McQueen     Chiwetel Ejiofor  Michael Kenneth Williams
# 216               Ron Howard         Daniel Brühl           Chris Hemsworth
# 222         Denis Villeneuve         Hugh Jackman           Jake Gyllenhaal
# 332            Isao Takahata   Chloë Grace Moretz                James Caan
# 335            Neeraj Pandey         Akshay Kumar               Anupam Kher
# 336    Destin Daniel Cretton          Brie Larson             Frantz Turner
# 341              Spike Jonze      Joaquin Phoenix                 Amy Adams
# 359         Jean-Marc Vallée  Matthew McConaughey           Jennifer Garner
# 478        Richard Linklater          Ethan Hawke               Julie Delpy
# 588           Asghar Farhadi        Bérénice Bejo               Tahar Rahim
# 589         Paolo Sorrentino        Toni Servillo             Carlo Verdone
# 590             Ritesh Batra          Irrfan Khan               Nimrat Kaur
# 593           Richard Curtis     Domhnall Gleeson            Rachel McAdams
# 595           Hayao Miyazaki         Hideaki Anno       Hidetoshi Nishijima
# 597       Giuseppe Tornatore        Geoffrey Rush              Jim Sturgess
# 604          Paul Greengrass            Tom Hanks              Barkhad Abdi
# 609            Peter Jackson         Ian McKellen            Martin Freeman
# 734      Abdellatif Kechiche          Léa Seydoux       Adèle Exarchopoulos
# 735          Abhishek Kapoor            Amit Sadh      Sushant Singh Rajput
# 739          Alexander Payne           Bruce Dern                Will Forte
# 745           Alfonso Cuarón       Sandra Bullock            George Clooney
# 746              J.J. Abrams           Chris Pine            Zachary Quinto
# 897           Stephen Frears           Judi Dench              Steve Coogan
#
#                        Star_3                Star_4  Total_Votes    Revenue
# 87               Asha Sharath                Ansiba        30722     288875
# 137               Lisa Haydon            Jeffrey Ho        60701    1429534
# 138         Giorgi Nakashidze          Misha Meskhi        40382     144501
# 139            Pawan Malhotra             Art Malik        61137    1626289
# 147             Margot Robbie   Matthew McConaughey       852113  116900694
# 215        Michael Fassbender             Brad Pitt       640533   56671993
# 216              Olivia Wilde  Alexandra Maria Lara       432811   26947624
# 222               Viola Davis           Melissa Leo       601149   61002302
# 332          Mary Steenburgen         James Marsden        38746    1506975
# 335            Manoj Bajpayee       Jimmy Sheirgill        51069    1079369
# 336        John Gallagher Jr.         Kaitlyn Dever        81770    1010414
# 341        Scarlett Johansson           Rooney Mara       540772   25568251
# 359                Jared Leto            Steve Zahn       441614   27298285
# 478  Seamus Davey-Fitzpatrick          Ariane Labed       141457    8114627
# 588               Ali Mosaffa        Pauline Burlet        45002    1330596
# 589           Sabrina Ferilli      Carlo Buccirosso        81125    2852400
# 590       Nawazuddin Siddiqui         Lillete Dubey        50523    4231500
# 593                Bill Nighy          Lydia Wilson       303032   15322921
# 595            Miori Takimoto    Masahiko Nishimura        73690    5209580
# 597              Sylvia Hoeks     Donald Sutherland       108399      85433
# 604        Barkhad Abdirahman      Catherine Keener       421244  107100855
# 609          Richard Armitage             Ken Stott       601408  181732323
# 734          Salim Kechiouche      Aurélien Recoing       138741    2199675
# 735             Rajkummar Rao           Amrita Puri        32628    1122527
# 739               June Squibb          Bob Odenkirk       112298   17654912
# 745                 Ed Harris      Orto Ignatiussen       769145  181732323
# 746               Zoe Saldana  Benedict Cumberbatch       463188  181732323
# 897      Sophie Kennedy Clark       Mare Winningham        94212   37707719

# %%
plt.hist(data.Runtime,edgecolor='black',bins=20)
plt.xlabel('Runtime')
plt.ylabel('No.of Movies')
plt.show()

# %% [markdown]
# ###***Observation:***
# #####Almost 130/1000 top movies have a duration of about 105 minutes. Below is the list of rows with a duration between 100 and 115.

# %%
data[(data['Runtime']>=100) & (data['Runtime']<=115)]
# Out:
#                       Title  Age  Certificate  Runtime  Genre  Rating  \
# 34                 Whiplash    9            0      106      6       8
# 35         The Intouchables   12           13      112      3       8
# 41       The Usual Suspects   28            0      106      5       8
# 42                     Léon   29            0      110      0       8
# 49                   Psycho   63            0      109     10       8
# ..                      ...  ...          ...      ...    ...     ...
# 981          On Golden Pond   42           13      109      6       7
# 985    Escape from Alcatraz   44            0      112      0       7
# 989        The Long Goodbye   50            0      112      4       7
# 993                  Blowup   57            0      111      6       7
# 995  Breakfast at Tiffany's   62            0      115      4       7
#
#                                               Overview  Meta_Score  \
# 34   A promising young drummer enrolls at a cut-thr...          88
# 35   After he becomes a quadriplegic from a paragli...          57
# 41   A sole survivor tells of the twisty events lea...          77
# 42   Mathilda, a 12-year-old girl, is reluctantly t...          64
# 49   A Phoenix secretary embezzles $40,000 from her...          97
# ..                                                 ...         ...
# 981  Norman is a curmudgeon with an estranged relat...          68
# 985  Alcatraz is the most secure prison of its time...          76
# 989  Private investigator Philip Marlowe helps a fr...          87
# 993  A fashion photographer unknowingly captures a ...          82
# 995  A young New York socialite becomes interested ...          76
#
#                    Director             Star_1             Star_2  \
# 34          Damien Chazelle       Miles Teller       J.K. Simmons
# 35          Olivier Nakache      Éric Toledano    François Cluzet
# 41             Bryan Singer       Kevin Spacey      Gabriel Byrne
# 42               Luc Besson          Jean Reno        Gary Oldman
# 49         Alfred Hitchcock    Anthony Perkins        Janet Leigh
# ..                      ...                ...                ...
# 981             Mark Rydell  Katharine Hepburn        Henry Fonda
# 985              Don Siegel     Clint Eastwood   Patrick McGoohan
# 989           Robert Altman      Elliott Gould  Nina van Pallandt
# 993  Michelangelo Antonioni        David Hemgs   Vanessa Redgrave
# 995           Blake Edwards     Audrey Hepburn     George Peppard
#
#               Star_3           Star_4  Total_Votes    Revenue
# 34   Melissa Benoist      Paul Reiser       717585   13092000
# 35           Omar Sy       Anne Le Ny       760360   13182281
# 41     Chazz Palteri  Stephen Baldwin       852113   23341568
# 42   Natalie Portman     Danny Aiello       852113   19501238
# 49        Vera Miles       John Gavin       604211   32000000
# ..               ...              ...          ...        ...
# 981       Jane Fonda      Doug McKeon        27650  119285432
# 985  Roberts Blossom     Jack Thibeau       121731   43000000
# 989  Sterling Hayden      Mark Rydell        26337     959000
# 993      Sarah Miles      John Castle        56513    1378635
# 995    Patricia Neal      Buddy Ebsen       166544    1378835
#
# [260 rows x 15 columns]

# %%
sns.barplot(x=data.Genre,y=data.Revenue,color='Violet')
plt.xlabel('Genre')
plt.ylabel('Revenue (in million)')
plt.title('Genre-Wise Revenue')
plt.show()
print(g_values)
# Out:
# Action        0
# Adventure     1
# Animation     2
# Biography     3
# Comedy        4
# Crime         5
# Drama         6
# Family        7
# Fantasy       8
# Film-Noir     9
# Horror       10
# Mystery      11
# Thriller     12
# Western      13
# dtype: int64

# %% [markdown]
# ###***Observation:***
# ##### Top 5 genres earning the highest revenue are: Family, Animation, Action, Horror and Biography.

# %%
sns.barplot(x=data.Rating,y=data.Revenue,color='Turquoise')
plt.xlabel('Rating')
plt.ylabel('Revenue (in million)')
plt.title('Rating-Wise Revenue')
plt.show()

# %% [markdown]
# ####***Observation:***
# #####Naturally, the top-rated movies earn the highest revenue.

# %%
sns.barplot(x=data.Genre,y=data.Rating,color='Gray')
plt.xlabel('Genre')
plt.ylabel('Rating')
plt.title('Rating Based on Genre')
plt.show()
print(g_values)
# Out:
# Action        0
# Adventure     1
# Animation     2
# Biography     3
# Comedy        4
# Crime         5
# Drama         6
# Family        7
# Fantasy       8
# Film-Noir     9
# Horror       10
# Mystery      11
# Thriller     12
# Western      13
# dtype: int64

# %% [markdown]
# ####***Observation:***
# #####All genres have a positive rating.

# %%
data.head()
# Out:
#                       Title  Age  Certificate  Runtime  Genre  Rating  \
# 0  The Shawshank Redemption   29            0      142      6       9
# 1             The Godfather   51            0      175      5       9
# 2           The Dark Knight   15           13      152      0       9
# 3    The Godfather: Part II   49            0      188      5       9
# 4              12 Angry Men   66           11       96      5       9
#
#                                             Overview  Meta_Score  \
# 0  Two imprisoned men bond over a number of years...          80
# 1  An organized crime dynasty's aging patriarch t...         100
# 2  When the menace known as the Joker wreaks havo...          84
# 3  The early life and career of Vito Corleone in ...          90
# 4  A jury holdout attempts to prevent a miscarria...          96
#
#                Director          Star_1          Star_2         Star_3  \
# 0        Frank Darabont     Tim Robbins  Morgan Freeman     Bob Gunton
# 1  Francis Ford Coppola   Marlon Brando       Al Pacino     James Caan
# 2     Christopher Nolan  Christian Bale    Heath Ledger  Aaron Eckhart
# 3  Francis Ford Coppola       Al Pacino  Robert De Niro  Robert Duvall
# 4          Sidney Lumet     Henry Fonda     Lee J. Cobb  Martin Balsam
#
#            Star_4  Total_Votes    Revenue
# 0  William Sadler       852113   28341469
# 1    Diane Keaton       852113  134966411
# 2   Michael Caine       852113  181732323
# 3    Diane Keaton       852113   57300000
# 4    John Fiedler       689845    4360000

# %% [markdown]
# Now that we've got some insights, let's proceed and build a predictive model.
# # *3. Training and Testing*

# %%
data.head()
# Out:
#                       Title  Age  Certificate  Runtime  Genre  Rating  \
# 0  The Shawshank Redemption   29            0      142      6       9
# 1             The Godfather   51            0      175      5       9
# 2           The Dark Knight   15           13      152      0       9
# 3    The Godfather: Part II   49            0      188      5       9
# 4              12 Angry Men   66           11       96      5       9
#
#                                             Overview  Meta_Score  \
# 0  Two imprisoned men bond over a number of years...          80
# 1  An organized crime dynasty's aging patriarch t...         100
# 2  When the menace known as the Joker wreaks havo...          84
# 3  The early life and career of Vito Corleone in ...          90
# 4  A jury holdout attempts to prevent a miscarria...          96
#
#                Director          Star_1          Star_2         Star_3  \
# 0        Frank Darabont     Tim Robbins  Morgan Freeman     Bob Gunton
# 1  Francis Ford Coppola   Marlon Brando       Al Pacino     James Caan
# 2     Christopher Nolan  Christian Bale    Heath Ledger  Aaron Eckhart
# 3  Francis Ford Coppola       Al Pacino  Robert De Niro  Robert Duvall
# 4          Sidney Lumet     Henry Fonda     Lee J. Cobb  Martin Balsam
#
#            Star_4  Total_Votes    Revenue
# 0  William Sadler       852113   28341469
# 1    Diane Keaton       852113  134966411
# 2   Michael Caine       852113  181732323
# 3    Diane Keaton       852113   57300000
# 4    John Fiedler       689845    4360000

# %% [markdown]
# ### ***Observation:***
# 'Revenue' is considered as the final output column.

# %% [markdown]
# First, we will scale our values.

# %%
scaler1=MinMaxScaler()
scaler2=StandardScaler()
scaler1.fit(data[['Runtime','Meta_Score','Revenue']])
scaler2.fit(data[['Rating','Total_Votes']])
data[['Runtime','Meta_Score','Revenue']]=scaler1.transform(data[['Runtime','Meta_Score','Revenue']])
data[['Rating','Total_Votes']]=scaler2.transform(data[['Rating','Total_Votes']])

# %%
data['Revenue']=data['Revenue']

# %% [markdown]
# Now, 'X' and 'Y' have been allotted their respective data.

# %%
X = data.drop(['Title','Overview','Director','Star_1','Star_2','Star_3','Star_4','Total_Votes','Revenue'], axis=1)
Y = data["Revenue"]

# %%
X.head()
# Out:
#    Age  Certificate   Runtime  Genre    Rating  Meta_Score
# 0   29            0  0.661765      6  3.010433    0.583333
# 1   51            0  0.904412      5  3.010433    1.000000
# 2   15           13  0.735294      0  3.010433    0.666667
# 3   49            0  1.000000      5  3.010433    0.791667
# 4   66           11  0.323529      5  3.010433    0.916667

# %%
Y.head()
# Out:
# 0    0.155946
# 1    0.742664
# 2    1.000000
# 3    0.315294
# 4    0.023984
# Name: Revenue, dtype: float64

# %%
data.shape
# Out:
# (1000, 15)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=21)

# %%
X_train.shape
# Out:
# (800, 6)

# %%
X_test.shape
# Out:
# (200, 6)

# %%
Y_train.shape
# Out:
# (800,)

# %%
Y_test.shape
# Out:
# (200,)

# %% [markdown]
# # *4. Feature Selection*

# %% [markdown]
# Selecting the best features for our model:

# %%
data.head()
# Out:
#                       Title  Age  Certificate   Runtime  Genre    Rating  \
# 0  The Shawshank Redemption   29            0  0.661765      6  3.010433
# 1             The Godfather   51            0  0.904412      5  3.010433
# 2           The Dark Knight   15           13  0.735294      0  3.010433
# 3    The Godfather: Part II   49            0  1.000000      5  3.010433
# 4              12 Angry Men   66           11  0.323529      5  3.010433
#
#                                             Overview  Meta_Score  \
# 0  Two imprisoned men bond over a number of years...    0.583333
# 1  An organized crime dynasty's aging patriarch t...    1.000000
# 2  When the menace known as the Joker wreaks havo...    0.666667
# 3  The early life and career of Vito Corleone in ...    0.791667
# 4  A jury holdout attempts to prevent a miscarria...    0.916667
#
#                Director          Star_1          Star_2         Star_3  \
# 0        Frank Darabont     Tim Robbins  Morgan Freeman     Bob Gunton
# 1  Francis Ford Coppola   Marlon Brando       Al Pacino     James Caan
# 2     Christopher Nolan  Christian Bale    Heath Ledger  Aaron Eckhart
# 3  Francis Ford Coppola       Al Pacino  Robert De Niro  Robert Duvall
# 4          Sidney Lumet     Henry Fonda     Lee J. Cobb  Martin Balsam
#
#            Star_4  Total_Votes   Revenue
# 0  William Sadler     2.371448  0.155946
# 1    Diane Keaton     2.371448  0.742664
# 2   Michael Caine     2.371448  1.000000
# 3    Diane Keaton     2.371448  0.315294
# 4    John Fiedler     1.731461  0.023984

# %%
bestfeatures=SelectKBest(mutual_info_regression,k=5)
bestfeatures.fit(X_train.values,Y_train.values)
X_train_selected=X_train[X_train.columns[bestfeatures.get_support()]]

# %%
X_train_selected.columns
# Out:
# Index(['Age', 'Certificate', 'Genre', 'Rating', 'Meta_Score'], dtype='object')

# %%
X_test_selected=X_test[X_test.columns[bestfeatures.get_support()]]

# %%
X_train_selected.shape
# Out:
# (800, 5)

# %%
X_test_selected.shape
# Out:
# (200, 5)

# %% [markdown]
# # *5. Modelling*

# %% [markdown]
# #### (i) Linear Regression

# %%
lr=LinearRegression()
lr.fit(X_train_selected,Y_train)
Y_pred=lr.predict(X_test_selected)

# %%
r2_1=r2_score(Y_test,Y_pred)
print("r2 is: {:.4f}".format(r2_1))
# Out:
# r2 is: 0.1377

# %%
mae1=metrics.mean_absolute_error(Y_test,Y_pred)
mse1=metrics.mean_squared_error(Y_test,Y_pred)
print("MAE is: {:.4f}".format(mae1))
print("MSE is: {:.4f}".format(mse1))
# Out:
# MAE is: 0.2379
# MSE is: 0.0910

# %%
rsme1=sqrt(mse1)
print("RSME is: {:.4f}".format(rsme1))
# Out:
# RSME is: 0.3017

# %% [markdown]
# #### (ii) Random Forest Regressor

# %%
rf=RandomForestRegressor(n_estimators=200,max_depth=5,min_samples_leaf=100,n_jobs=4,random_state=22)
rf.fit(X_train_selected,Y_train)
Y_pred=rf.predict(X_test_selected)

# %%
r2_2=r2_score(Y_test,Y_pred)
print("r2 is: {:.4f}".format(r2_2))
# Out:
# r2 is: 0.1484

# %%
mae2=metrics.mean_absolute_error(Y_test,Y_pred)
mse2=metrics.mean_squared_error(Y_test,Y_pred)
print("MAE is: {:.4f}".format(mae2))
print("MSE is: {:.4f}".format(mse2))
# Out:
# MAE is: 0.2384
# MSE is: 0.0899

# %%
rsme2=sqrt(mse2)
print("RSME is: {:.4f}".format(rsme2))
# Out:
# RSME is: 0.2998

# %% [markdown]
# #### (iii) XG Boost *Regressor*

# %%
from xgboost import XGBRegressor
xg=XGBRegressor()
xg.fit(X_train_selected,Y_train)
Y_pred=xg.predict(X_test_selected)

# %%
r2_3=r2_score(Y_test,Y_pred)
print("r2 is: {:.4f}".format(r2_3))
# Out:
# r2 is: -0.1294

# %%
mae3=metrics.mean_absolute_error(Y_test,Y_pred)
mse3=metrics.mean_squared_error(Y_test,Y_pred)
print("MAE is: {:.4f}".format(mae3))
print("MSE is: {:.4f}".format(mse3))
# Out:
# MAE is: 0.2499
# MSE is: 0.1192

# %%
rsme3=sqrt(mse3)
print("RSME is: {:.4f}".format(rsme3))
# Out:
# RSME is: 0.3452

# %% [markdown]
# Linear Regression Model gives the least RSME value,: hence that will be used as our algorithm.

# %%
features=X_train_selected.columns

# %%
X_train_selected.head()
# Out:
#      Age  Certificate  Genre    Rating  Meta_Score
# 108   40            0      5  1.045399    0.270833
# 134    6           13      0  1.045399    0.562500
# 585    4           11      6 -0.919636    0.812500
# 42    29            0      0  1.045399    0.250000
# 990   52            4      6 -0.919636    0.520833

# %%
print('Variable References:\n')
for i in X_train_selected.columns:
  print(i,":-\n",'Min. value: {:.2f}'.format(X_train_selected[i].min()),'\tMax. value:{:.2f}'.format(X_train_selected[i].max()))
  print('\n')
# Out:
# Variable References:
#
# Age :-
#  Min. value: 3.00 	Max. value:96.00
#
#
# Certificate :-
#  Min. value: 0.00 	Max. value:14.00
#
#
# Genre :-
#  Min. value: 0.00 	Max. value:12.00
#
#
# Rating :-
#  Min. value: -0.92 	Max. value:3.01
#
#
# Meta_Score :-
#  Min. value: 0.00 	Max. value:1.00

# %%
data.head()
# Out:
#                       Title  Age  Certificate   Runtime  Genre    Rating  \
# 0  The Shawshank Redemption   29            0  0.661765      6  3.010433
# 1             The Godfather   51            0  0.904412      5  3.010433
# 2           The Dark Knight   15           13  0.735294      0  3.010433
# 3    The Godfather: Part II   49            0  1.000000      5  3.010433
# 4              12 Angry Men   66           11  0.323529      5  3.010433
#
#                                             Overview  Meta_Score  \
# 0  Two imprisoned men bond over a number of years...    0.583333
# 1  An organized crime dynasty's aging patriarch t...    1.000000
# 2  When the menace known as the Joker wreaks havo...    0.666667
# 3  The early life and career of Vito Corleone in ...    0.791667
# 4  A jury holdout attempts to prevent a miscarria...    0.916667
#
#                Director          Star_1          Star_2         Star_3  \
# 0        Frank Darabont     Tim Robbins  Morgan Freeman     Bob Gunton
# 1  Francis Ford Coppola   Marlon Brando       Al Pacino     James Caan
# 2     Christopher Nolan  Christian Bale    Heath Ledger  Aaron Eckhart
# 3  Francis Ford Coppola       Al Pacino  Robert De Niro  Robert Duvall
# 4          Sidney Lumet     Henry Fonda     Lee J. Cobb  Martin Balsam
#
#            Star_4  Total_Votes   Revenue
# 0  William Sadler     2.371448  0.155946
# 1    Diane Keaton     2.371448  0.742664
# 2   Michael Caine     2.371448  1.000000
# 3    Diane Keaton     2.371448  0.315294
# 4    John Fiedler     1.731461  0.023984

# %%
inputs=[]
for f in features:
    f=float(input(f'Enter {f}:'))
    inputs.append(f)
# Out:
# Enter Age:30
# Enter Certificate:7
# Enter Genre:5
# Enter Rating:2.5
# Enter Meta_Score:0.9

# %%
i=np.array(inputs)
i=i.reshape(1,-1)
ans=lr.predict(i).round(2)
print('The revenue is predicted as',ans[0])
# Out:
# The revenue is predicted as 0.29

# %% [markdown]
# # ***II. Deep Learning - ANN (Artificial Neural Network)  Model***

# %%
data.head()
# Out:
#                       Title  Age  Certificate   Runtime  Genre    Rating  \
# 0  The Shawshank Redemption   29            0  0.661765      6  3.010433
# 1             The Godfather   51            0  0.904412      5  3.010433
# 2           The Dark Knight   15           13  0.735294      0  3.010433
# 3    The Godfather: Part II   49            0  1.000000      5  3.010433
# 4              12 Angry Men   66           11  0.323529      5  3.010433
#
#                                             Overview  Meta_Score  \
# 0  Two imprisoned men bond over a number of years...    0.583333
# 1  An organized crime dynasty's aging patriarch t...    1.000000
# 2  When the menace known as the Joker wreaks havo...    0.666667
# 3  The early life and career of Vito Corleone in ...    0.791667
# 4  A jury holdout attempts to prevent a miscarria...    0.916667
#
#                Director          Star_1          Star_2         Star_3  \
# 0        Frank Darabont     Tim Robbins  Morgan Freeman     Bob Gunton
# 1  Francis Ford Coppola   Marlon Brando       Al Pacino     James Caan
# 2     Christopher Nolan  Christian Bale    Heath Ledger  Aaron Eckhart
# 3  Francis Ford Coppola       Al Pacino  Robert De Niro  Robert Duvall
# 4          Sidney Lumet     Henry Fonda     Lee J. Cobb  Martin Balsam
#
#            Star_4  Total_Votes   Revenue
# 0  William Sadler     2.371448  0.155946
# 1    Diane Keaton     2.371448  0.742664
# 2   Michael Caine     2.371448  1.000000
# 3    Diane Keaton     2.371448  0.315294
# 4    John Fiedler     1.731461  0.023984

# %% [markdown]
# Since the data is a regression problem, we use Linear activation function.

# %%
X_train.shape
# Out:
# (800, 6)

# %%
classifier=Sequential()
classifier.add(Dense(units=10,activation='linear',input_dim=6))

# %%
classifier.add(Dense(units=6,activation='linear'))

# %%
classifier.add(Dense(units=1,activation='linear'))

# %%
classifier.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 10)                70
#
#  dense_1 (Dense)             (None, 6)                 66
#
#  dense_2 (Dense)             (None, 1)                 7
#
# =================================================================
# Total params: 143
# Trainable params: 143
# Non-trainable params: 0
# _________________________________________________________________

# %%
classifier.compile(optimizer='adam',loss=['mae','mse'],metrics=['accuracy'])

# %%
model=classifier.fit(X_train,Y_train,validation_split=0.33,batch_size=10,epochs=50)
# Out:
# Epoch 1/50
# 54/54 [==============================] - 1s 6ms/step - loss: 3.8418 - accuracy: 0.0205 - val_loss: 0.5386 - val_accuracy: 0.0265
# Epoch 2/50
# 54/54 [==============================] - 0s 3ms/step - loss: 0.4800 - accuracy: 0.0522 - val_loss: 0.3749 - val_accuracy: 0.0379
# Epoch 3/50
# 54/54 [==============================] - 0s 4ms/step - loss: 0.3588 - accuracy: 0.0429 - val_loss: 0.3016 - val_accuracy: 0.0417
# Epoch 4/50
# 54/54 [==============================] - 0s 3ms/step - loss: 0.3347 - accuracy: 0.0392 - val_loss: 0.3832 - val_accuracy: 0.0606
# Epoch 5/50
# 54/54 [==============================] - 0s 3ms/step - loss: 0.3051 - accuracy: 0.0392 - val_loss: 0.2946 - val_accuracy: 0.0303
# Epoch 6/50
# 54/54 [==============================] - 0s 3ms/step - loss: 0.3146 - accuracy: 0.0261 - val_loss: 0.3743 - val_accuracy: 0.0303
# Epoch 7/50
# 54/54 [==============================] - 0s 4ms/step - loss: 0.3111 - accuracy: 0.0317 - val_loss: 0.3250 - val_accuracy: 0.0303
# Epoch 8/50
# 54/54 [==============================] - 0s 3ms/step - loss: 0.2827 - accuracy: 0.0243 - val_loss: 0.2713 - val_accuracy: 0.0114
# Epoch 9/50
# 54/54 [==============================] - 0s 3ms/step - loss: 0.2994 - accuracy: 0.0168 - val_loss: 0.2578 - val_accuracy: 0.0492
# Epoch 10/50
# 54/54 [==============================] - 0s 3ms/step - loss: 0.3170 - accuracy: 0.0131 - val_loss: 0.2430 - val_accuracy: 0.0114
# Epoch 11/50
# 54/54 [==============================] - 0s 3ms/step - loss: 0.2866 - accuracy: 0.0149 - val_loss: 0.2560 - val_accuracy: 0.0114
# Epoch 12/50
# 54/54 [==============================] - 0s 3ms/step - loss: 0.2708 - accuracy: 0.0112 - val_loss: 0.3221 - val_accuracy: 0.0038
# Epoch 13/50
# 54/54 [==============================] - 0s 5ms/step - loss: 0.2691 - accuracy: 0.0000e+00 - val_loss: 0.2392 - val_accuracy: 0.0114
# Epoch 14/50
# 54/54 [==============================] - 0s 4ms/step - loss: 0.3083 - accuracy: 0.0093 - val_loss: 0.2942 - val_accuracy: 0.0530
# Epoch 15/50
# 54/54 [==============================] - 0s 4ms/step - loss: 0.2923 - accuracy: 0.0112 - val_loss: 0.2418 - val_accuracy: 0.0114
# Epoch 16/50
# 54/54 [==============================] - 0s 4ms/step - loss: 0.2696 - accuracy: 0.0019 - val_loss: 0.2579 - val_accuracy: 0.0265
# Epoch 17/50
# 54/54 [==============================] - 0s 5ms/step - loss: 0.3024 - accuracy: 0.0112 - val_loss: 0.3734 - val_accuracy: 0.0038
# Epoch 18/50
# 54/54 [==============================] - 0s 5ms/step - loss: 0.2998 - accuracy: 0.0168 - val_loss: 0.2866 - val_accuracy: 0.0265
# Epoch 19/50
# 54/54 [==============================] - 0s 4ms/step - loss: 0.2634 - accuracy: 0.0075 - val_loss: 0.2381 - val_accuracy: 0.0076
# Epoch 20/50
# 54/54 [==============================] - 0s 4ms/step - loss: 0.2664 - accuracy: 0.0019 - val_loss: 0.2475 - val_accuracy: 0.0114
# Epoch 21/50
# 54/54 [==============================] - 0s 4ms/step - loss: 0.2694 - accuracy: 0.0037 - val_loss: 0.3423 - val_accuracy: 0.0152
# Epoch 22/50
# 54/54 [==============================] - 0s 4ms/step - loss: 0.2929 - accuracy: 0.0037 - val_loss: 0.2618 - val_accuracy: 0.0152
# Epoch 23/50
# 54/54 [==============================] - 0s 4ms/step - loss: 0.3156 - accuracy: 0.0093 - val_loss: 0.2398 - val_accuracy: 0.0038
# Epoch 24/50
# 54/54 [==============================] - 0s 4ms/step - loss: 0.2685 - accuracy: 0.0093 - val_loss: 0.2475 - val_accuracy: 0.0076
# Epoch 25/50
# 54/54 [==============================] - 0s 3ms/step - loss: 0.2844 - accuracy: 0.0037 - val_loss: 0.2709 - val_accuracy: 0.0152
# Epoch 26/50
# 54/54 [==============================] - 0s 3ms/step - loss: 0.2738 - accuracy: 0.0037 - val_loss: 0.2776 - val_accuracy: 0.0038
# Epoch 27/50
# 54/54 [==============================] - 0s 3ms/step - loss: 0.2739 - accuracy: 0.0019 - val_loss: 0.2971 - val_accuracy: 0.0227
# Epoch 28/50
# 54/54 [==============================] - 0s 3ms/step - loss: 0.2746 - accuracy: 0.0037 - val_loss: 0.3859 - val_accuracy: 0.0417
# Epoch 29/50
# 54/54 [==============================] - 0s 3ms/step - loss: 0.3030 - accuracy: 0.0075 - val_loss: 0.2407 - val_accuracy: 0.0038
# Epoch 30/50
# 54/54 [==============================] - 0s 4ms/step - loss: 0.3002 - accuracy: 0.0149 - val_loss: 0.2470 - val_accuracy: 0.0189
# Epoch 31/50
# 54/54 [==============================] - 0s 4ms/step - loss: 0.3042 - accuracy: 0.0019 - val_loss: 0.2444 - val_accuracy: 0.0265
# Epoch 32/50
# 54/54 [==============================] - 0s 4ms/step - loss: 0.2823 - accuracy: 0.0037 - val_loss: 0.3042 - val_accuracy: 0.0038
# Epoch 33/50
# 54/54 [==============================] - 0s 3ms/step - loss: 0.2852 - accuracy: 0.0000e+00 - val_loss: 0.2810 - val_accuracy: 0.0038
# Epoch 34/50
# 54/54 [==============================] - 0s 3ms/step - loss: 0.2596 - accuracy: 0.0037 - val_loss: 0.2336 - val_accuracy: 0.0038
# Epoch 35/50
# 54/54 [==============================] - 0s 3ms/step - loss: 0.2590 - accuracy: 0.0000e+00 - val_loss: 0.2579 - val_accuracy: 0.0303
# Epoch 36/50
# 54/54 [==============================] - 0s 3ms/step - loss: 0.2623 - accuracy: 0.0037 - val_loss: 0.2459 - val_accuracy: 0.0038
# Epoch 37/50
# 54/54 [==============================] - 0s 4ms/step - loss: 0.2650 - accuracy: 0.0000e+00 - val_loss: 0.2322 - val_accuracy: 0.0038
# Epoch 38/50
# 54/54 [==============================] - 0s 3ms/step - loss: 0.2683 - accuracy: 0.0056 - val_loss: 0.2432 - val_accuracy: 0.0038
# Epoch 39/50
# 54/54 [==============================] - 0s 3ms/step - loss: 0.2614 - accuracy: 0.0000e+00 - val_loss: 0.2350 - val_accuracy: 0.0038
# Epoch 40/50
# 54/54 [==============================] - 0s 3ms/step - loss: 0.2901 - accuracy: 0.0056 - val_loss: 0.3159 - val_accuracy: 0.0152
# Epoch 41/50
# 54/54 [==============================] - 0s 3ms/step - loss: 0.2819 - accuracy: 0.0149 - val_loss: 0.2790 - val_accuracy: 0.0038
# Epoch 42/50
# 54/54 [==============================] - 0s 3ms/step - loss: 0.2740 - accuracy: 0.0037 - val_loss: 0.3046 - val_accuracy: 0.0189
# Epoch 43/50
# 54/54 [==============================] - 0s 4ms/step - loss: 0.2855 - accuracy: 0.0056 - val_loss: 0.2428 - val_accuracy: 0.0038
# Epoch 44/50
# 54/54 [==============================] - 0s 3ms/step - loss: 0.3012 - accuracy: 0.0019 - val_loss: 0.2430 - val_accuracy: 0.0038
# Epoch 45/50
# 54/54 [==============================] - 0s 3ms/step - loss: 0.2685 - accuracy: 0.0037 - val_loss: 0.2274 - val_accuracy: 0.0038
# Epoch 46/50
# 54/54 [==============================] - 0s 3ms/step - loss: 0.2842 - accuracy: 0.0037 - val_loss: 0.3260 - val_accuracy: 0.0189
# Epoch 47/50
# 54/54 [==============================] - 0s 3ms/step - loss: 0.2675 - accuracy: 0.0019 - val_loss: 0.2394 - val_accuracy: 0.0038
# Epoch 48/50
# 54/54 [==============================] - 0s 3ms/step - loss: 0.2642 - accuracy: 0.0000e+00 - val_loss: 0.2914 - val_accuracy: 0.0152
# Epoch 49/50
# 54/54 [==============================] - 0s 3ms/step - loss: 0.2656 - accuracy: 0.0019 - val_loss: 0.3062 - val_accuracy: 0.0038
# Epoch 50/50
# 54/54 [==============================] - 0s 3ms/step - loss: 0.2674 - accuracy: 0.0000e+00 - val_loss: 0.2290 - val_accuracy: 0.0038

# %%
print (model.history.keys())
plt.plot(model.history['accuracy'])
plt.plot(model.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('EPoch')
plt.legend (['Train', 'Test'], loc='upper left')
plt.show()
print('\n','\n','\n','\n')
plt.plot(model.history['loss'])
plt.plot(model.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('EPoch')
plt.legend (['Train', 'Test'], loc='upper right')
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %% [markdown]
# ###***Observation:***
# ####Accuracy increases and loss decreases in the testing part.

# %%
Y_pred=classifier.predict(X_test)
mae4=metrics.mean_absolute_error(Y_test,Y_pred)
mse4=metrics.mean_squared_error(Y_test,Y_pred)
# Out:
# 7/7 [==============================] - 0s 2ms/step

# %%
print("MAE is: {:.2f}".format(mae4))
print("MSE is: {:.2f}".format(mse4))
# Out:
# MAE is: 0.23
# MSE is: 0.10

# %%
print(Y_test)
# Out:
# 492    0.006518
# 383    0.123560
# 856    0.249262
# 834    0.047047
# 603    0.564100
#          ...
# 72     1.000000
# 400    0.387409
# 813    0.055125
# 195    0.020682
# 45     0.065972
# Name: Revenue, Length: 200, dtype: float64

# %%
rsme=sqrt(mse4)
print("RSME is {:.2f}".format(rsme))
# Out:
# RSME is 0.32
